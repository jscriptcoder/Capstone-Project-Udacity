# %% [markdown]
# ### Data Exploration & Visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Loading Apple Inc. stock prices that can be easily downloaded for free from [Yahoo! Finance](https://finance.yahoo.com/quote/AAPL/history?p=AAPL)

# %%
def load_csv_with_dates(file):
    return pd.read_csv(file, 
                       index_col=0, 
                       parse_dates=True, 
                       infer_datetime_format=True)

# %%
apple_stock = load_csv_with_dates('datasets/AAPL_yahoo-finance_19801212-20190531.csv')

# for the sake of simplicity I'm gonna drop Adj Close column
apple_stock.drop(columns='Adj Close', inplace=True)

# %%
apple_stock.head()
# Out:
#                 Open      High       Low     Close       Volume
# Date
# 1980-12-12  0.513393  0.515625  0.513393  0.513393  117258400.0
# 1980-12-15  0.488839  0.488839  0.486607  0.486607   43971200.0
# 1980-12-16  0.453125  0.453125  0.450893  0.450893   26432000.0
# 1980-12-17  0.462054  0.464286  0.462054  0.462054   21610400.0
# 1980-12-18  0.475446  0.477679  0.475446  0.475446   18362400.0

# %%
print('Total data points: {}'.format(len(apple_stock)))
print('From {} to {}'.format(apple_stock.index[0], apple_stock.index[-1]))
# Out:
# Total data points: 9699
# From 1980-12-12 00:00:00 to 2019-05-31 00:00:00

# %%
Do we have null values?
# Out:
# Object `values` not found.

# %% [markdown]
# Do we have null values? and how many?

# %%
apple_stock.isnull().any()
# Out:
# Open      True
# High      True
# Low       True
# Close     True
# Volume    True
# dtype: bool

# %%
apple_stock.isnull().sum()
# Out:
# Open      1
# High      1
# Low       1
# Close     1
# Volume    1
# dtype: int64

# %%
apple_stock[apple_stock['Close'].isnull()]
# Out:
#             Open  High  Low  Close  Volume
# Date
# 1981-08-10   NaN   NaN  NaN    NaN     NaN

# %%
def get_range(start, end, df):
    return df[(df.index >= start) & (df.index <= end)]

# %%
get_range('1981-08-07', '1981-08-11', apple_stock)
# Out:
#                 Open      High       Low     Close      Volume
# Date
# 1981-08-07  0.450893  0.453125  0.450893  0.450893   2301600.0
# 1981-08-10       NaN       NaN       NaN       NaN         NaN
# 1981-08-11  0.441964  0.441964  0.437500  0.437500  17864000.0

# %% [markdown]
# Let's populate this value with the previous one

# %%
apple_stock.loc['1981-08-10'] = apple_stock.loc['1981-08-07']

# %%
get_range('1981-08-07', '1981-08-11', apple_stock)
# Out:
#                 Open      High       Low     Close      Volume
# Date
# 1981-08-07  0.450893  0.453125  0.450893  0.450893   2301600.0
# 1981-08-10  0.450893  0.453125  0.450893  0.450893   2301600.0
# 1981-08-11  0.441964  0.441964  0.437500  0.437500  17864000.0

# %% [markdown]
# Descriptive Statistics:

# %%
apple_stock.describe()
# Out:
#               Open         High          Low        Close        Volume
# count  9698.000000  9698.000000  9698.000000  9698.000000  9.698000e+03
# mean     27.946123    28.215623    27.662742    27.946056  8.697721e+07
# std      49.279331    49.709499    48.845790    49.290084  8.650311e+07
# min       0.198661     0.198661     0.196429     0.196429  3.472000e+05
# 25%       1.057143     1.077924     1.035714     1.058036  3.368798e+07
# 50%       1.678929     1.719375     1.651786     1.683661  5.881330e+07
# 75%      27.435714    27.762501    27.097857    27.380714  1.084872e+08
# max     230.779999   233.470001   229.779999   232.070007  1.855410e+09

# %% [markdown]
# Let's plot the closing prices over time

# %%
def plot_field_over_time(df, title, ylabel=None, xlabel='Year', ylegend=None, y='Close', figsize=(15, 4)):
    ax = df.reset_index().plot(x='Date', 
                               y=y, 
                               title=title,
                               figsize=figsize)
    ax.set_xlabel(xlabel)
    
    if ylabel is not None:
        ax.set_ylabel(ylabel)
    
    if ylegend is not None:
        ax.legend([ylegend])

# %%
plot_field_over_time(apple_stock, ylabel='Price', ylegend='Close Price', title='Apple Inc. (AAPL)')

# %% [markdown]
# The dataset is non-stationary, meaning that the mean and the variance of the observations change over time

# %% [markdown]
# How about the volumen?

# %%
plot_field_over_time(apple_stock, y='Volume', ylabel='Trading Volume', title='Apple Inc. (AAPL)')

# %%
apple_stock[['Volume']].boxplot(figsize=(15, 6))

# %% [markdown]
# Distribution of observations, it means values without the temporal ordering:

# %%
apple_stock[['Close', 'Volume']].hist(figsize=(15, 6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a2baacb00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2bb15978>]],
#       dtype=object)

# %% [markdown]
# Let's zoom in and plot 2015, 2016, 2017 and 2018 prices:

# %%
apple_stock_2015 = get_range('2015-01-01', '2015-12-31', apple_stock)
apple_stock_2016 = get_range('2016-01-01', '2016-12-31', apple_stock)
apple_stock_2017 = get_range('2017-01-01', '2017-12-31', apple_stock)
apple_stock_2018 = get_range('2018-01-01', '2018-12-31', apple_stock)

# %%
plot_field_over_time(apple_stock_2015, 
                     xlabel='Year 2015', 
                     ylabel='Price', 
                     ylegend='Close Price', 
                     title='Apple Inc. in 2015')

plot_field_over_time(apple_stock_2016, 
                     xlabel='Year 2016', 
                     ylabel='Price', 
                     ylegend='Close Price', 
                     title='Apple Inc. in 2016')

plot_field_over_time(apple_stock_2017, 
                     xlabel='Year 2017', 
                     ylabel='Price', 
                     ylegend='Close Price', 
                     title='Apple Inc. in 2017')

plot_field_over_time(apple_stock_2018, 
                     xlabel='Year 2018', 
                     ylabel='Price', 
                     ylegend='Close Price', 
                     title='Apple Inc. in 2018')

# %% [markdown]
# A nice visualization would be using candlesticks. We need to import the necessary libs

# %%
import matplotlib.dates as mdates
from mpl_finance import candlestick_ohlc

# %%
def plot_candlestick(title, xlabel, ylabel, df, figsize=(15, 4)):
    fig, ax = plt.subplots(figsize=figsize)
    candlestick_ohlc(ax, 
                     zip(mdates.date2num(df.index.to_pydatetime()), 
                         df['Open'], 
                         df['High'], 
                         df['Low'], 
                         df['Close']), 
                     width=0.6, 
                     colorup='g')
    ax.xaxis_date()
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    plt.show()

# %%
plot_candlestick('Apple Inc. in 2018', 'Year 2018', 'Price', apple_stock_2018)

# %% [markdown]
# Let's zoom in a bit more. Oct, Nov and Dec 2018:

# %%
apple_stock_201810 = get_range('2018-10-01', '2018-10-31', apple_stock)
apple_stock_201811 = get_range('2018-11-01', '2018-11-30', apple_stock)
apple_stock_201812 = get_range('2018-12-01', '2018-12-31', apple_stock)

# %%
plot_candlestick('Apple Inc. in 2018-10', 'Oct 2018', 'Price', apple_stock_201810)
plot_candlestick('Apple Inc. in 2018-11', 'Nov 2018', 'Price', apple_stock_201811)
plot_candlestick('Apple Inc. in 2018-12', 'Dec 2018', 'Price', apple_stock_201812)

# %% [markdown]
# I'd be curious to know what the time series look like after adjusting inflation. We need to first load the [Consumer Price Index for All Urban Consumers: All Items](https://fred.stlouisfed.org/series/CPIAUCSL)

# %%
# cpi = load_csv_with_dates('datasets/CPIAUCSL_FRED_19470101-20190401.csv') # Seasonally Adjusted
cpi = load_csv_with_dates('datasets/CPIAUCNS_FRED-19130101-20190401.csv') # Not Seasonally Adjusted

# We need to rename the index to be able to merge later on
cpi.rename_axis('Date', inplace=True)

# %%
cpi.head()
# Out:
#             CPIAUCNS
# Date
# 1913-01-01       9.8
# 1913-02-01       9.8
# 1913-03-01       9.8
# 1913-04-01       9.8
# 1913-05-01       9.7

# %%
print('Consumer Price Index from {} to {}'.format(cpi.index[0], cpi.index[-1]))
# Out:
# Consumer Price Index from 1913-01-01 00:00:00 to 2019-04-01 00:00:00

# %% [markdown]
# Let's visualize the inflation:

# %%
plot_field_over_time(cpi, y='CPIAUCNS', title='Consumer Price Index')

# %% [markdown]
# We're gonna add a new column, CPI_multiplier ([reference](https://towardsdatascience.com/adjusting-prices-for-inflation-in-pandas-daaaa782cd89))

# %%
cpi_with_mul = cpi.copy()
cpi_with_mul['CPI_Multiplier'] = cpi['CPIAUCNS'].iloc[-1] / cpi['CPIAUCNS']

# %%
cpi_with_mul.tail()
# Out:
#             CPIAUCNS  CPI_Multiplier
# Date
# 2018-12-01   251.233        1.017175
# 2019-01-01   251.712        1.015240
# 2019-02-01   252.776        1.010966
# 2019-03-01   254.202        1.005295
# 2019-04-01   255.548        1.000000

# %%
apple_stock_with_cpi = pd.merge(apple_stock, cpi_with_mul, left_index=True, right_index=True)

# %%
apple_stock_with_cpi['CPI_Adjusted_Price'] = \
    apple_stock_with_cpi['Close'] * apple_stock_with_cpi['CPI_Multiplier']

# %%
plot_field_over_time(apple_stock_with_cpi, 
                     y='CPI_Adjusted_Price', 
                     ylabel='Price', 
                     ylegend='Close Price',
                     title='Apple Inc. with adjusted inflation')

# %% [markdown]
# Let's plot both with and without adjusted inflation to better see the difference:

# %%
apple_close_with_cpi = pd.merge(apple_stock['Close'], apple_stock_with_cpi['CPI_Adjusted_Price'], left_index=True, right_index=True)

# %%
apple_close_with_cpi.plot(figsize=(15, 6))

# %% [markdown]
# Lag scatter plots:

# %%
from pandas.plotting import lag_plot, autocorrelation_plot

# %%
fig, ax = plt.subplots(figsize=(15, 6))
lag_plot(apple_stock['Close'], lag=1, ax=ax)

# %%
fig, ax = plt.subplots(figsize=(15, 6))
autocorrelation_plot(apple_stock['Close'][:15], ax=ax)

# %% [markdown]
# ### Trend and Seasonality

# %% [markdown]
# A trend can be removed from your time series data (and data in the future) as a data preparation and cleaning exercise. This is common when using statistical methods for time series forecasting, but does not always improve results when using machine learning models. Alternately, a trend can be added, either directly or as a summary, as a new input variable to the supervised learning problem to predict the output variable.

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.linear_model import LinearRegression

# %%
X = np.array([i for i in range(0, len(apple_stock))]).reshape(-1, 1)
y = np.array(apple_stock['Close']).reshape(-1, 1)

# %%
linear_regressor = LinearRegression()
linear_regressor.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
trend = linear_regressor.predict(X)

# %%
fig, ax = plt.subplots(figsize=(15, 6))
plt.plot(y)
plt.plot(trend)
ax.set_title('Apple Close price trend')
ax.legend(['Close price', 'Trend'])

# %%
detrended = [y[i]-trend[i] for i in range(0, len(apple_stock))]

# %%
plt.subplots(figsize=(15, 6))
plt.plot(detrended)

# %% [markdown]
# There seems to be a parabola in the residuals, suggesting that perhaps a polynomial fit may have done a better job

# %%
from numpy import polyfit

# %%
degree = 4
X1d = X.flatten()
y1d = y.flatten()
coef = polyfit(X1d, y1d, degree) 
print('Coefficients: %s' % coef)
# Out:
# Coefficients: [ 7.54976179e-14 -6.34434429e-10  1.09348033e-06  1.11300850e-03
#  -6.38825752e-01]

# %%
# create curve
curve = list()
for i in range(len(X)):
    value = coef[-1]
    for d in range(degree):
        value += X[i]**(degree-d) * coef[d]
    curve.append(value)
    
# plot curve over original data
plt.subplots(figsize=(15, 6))
plt.plot(y)
plt.plot(curve, color='red', linewidth=3)

# %%
detrended = [y[i]-curve[i] for i in range(0, len(apple_stock))]

# %%
plt.subplots(figsize=(15, 6))
plt.plot(detrended)

# %% [markdown]
# ### Train/Test Split

# %% [markdown]
# We're gonna try to predict 1 day, 1 week, 1 months, 6 months and a whole year

# %%
size_train = round(len(apple_stock) * 0.95) # 95% train, 5% test
size_test = len(apple_stock) - size_train

detrended_train = detrended[:size_train]
detrended_test = detrended[size_train:]

apple_train = apple_stock[:size_train]
apple_test = apple_stock[size_train:]

# %%
print('Total size {}. Train size {}. Test size {}'.format(len(detrended), size_train, size_test))
# Out:
# Total size 9699. Train size 9214. Test size 485

# %%
apple_test.head()
# Out:
#                   Open        High         Low       Close      Volume
# Date
# 2017-06-27  145.009995  146.160004  143.619995  143.729996  24761900.0
# 2017-06-28  144.490005  146.110001  143.160004  145.830002  22082400.0
# 2017-06-29  144.710007  145.130005  142.279999  143.679993  31499400.0
# 2017-06-30  144.449997  144.960007  143.779999  144.020004  23024100.0
# 2017-07-03  144.880005  145.300003  143.100006  143.500000  14277800.0

# %%
X_train = apple_train.drop('Close', axis=1)
y_train = apple_train['Close']
X_test = apple_test.drop('Close', axis=1)
y_test = apple_test['Close']

# %%
X_train.head()
# Out:
#                 Open      High       Low       Volume
# Date
# 1980-12-12  0.513393  0.515625  0.513393  117258400.0
# 1980-12-15  0.488839  0.488839  0.486607   43971200.0
# 1980-12-16  0.453125  0.453125  0.450893   26432000.0
# 1980-12-17  0.462054  0.464286  0.462054   21610400.0
# 1980-12-18  0.475446  0.477679  0.475446   18362400.0

# %%
y_train.head()
# Out:
# Date
# 1980-12-12    0.513393
# 1980-12-15    0.486607
# 1980-12-16    0.450893
# 1980-12-17    0.462054
# 1980-12-18    0.475446
# Name: Close, dtype: float64

# %% [markdown]
# ### ARIMA Model

# %% [markdown]
# An ARIMA model is a class of statistical models for analyzing and forecasting time series data. It explicitly caters to a suite of standard structures in time series data, and as such provides a simple yet powerful method for making skillful time series forecasts. ARIMA is an acronym that stands for AutoRegressive Integrated Moving Average. It is a generalization of the simpler AutoRegressive Moving Average and adds the notion of integration. This acronym is descriptive, capturing the key aspects of the model itself. Briefly, they are:
# - AR: Autoregression. A model that uses the dependent relationship between an observation and some number of lagged observations.
# - I: Integrated. The use of differencing of raw observations (e.g. subtracting an observation from an observation at the previous time step) in order to make the time series stationary.
# - MA: Moving Average. A model that uses the dependency between an observation and a residual error from a moving average model applied to lagged observations.

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
model = ARIMA(y_train, order=(2,1,0))
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
model_fit = model.fit(disp=0)

# %%
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.Close   No. Observations:                 9213
# Model:                 ARIMA(2, 1, 0)   Log Likelihood               -8848.101
# Method:                       css-mle   S.D. of innovations              0.632
# Date:                Tue, 11 Jun 2019   AIC                          17704.202
# Time:                        21:39:07   BIC                          17732.715
# Sample:                             1   HQIC                         17713.893
#
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0158      0.007      2.409      0.016       0.003       0.029
# ar.L1.D.Close     0.0168      0.010      1.611      0.107      -0.004       0.037
# ar.L2.D.Close    -0.0227      0.010     -2.184      0.029      -0.043      -0.002
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.3689           -6.6203j            6.6306           -0.2411
# AR.2            0.3689           +6.6203j            6.6306            0.2411
# -----------------------------------------------------------------------------

# %%
residuals = pd.DataFrame(model_fit.resid)
residuals.plot(figsize=(15, 6))

# %%
residuals.plot(kind='kde', figsize=(15, 6))

# %%
residuals.describe()
# Out:
#                   0
# count  9.213000e+03
# mean  -1.532371e-07
# std    6.322368e-01
# min   -9.095378e+00
# 25%   -4.584806e-02
# 50%   -1.549861e-02
# 75%    2.300881e-02
# max    7.381557e+00

# %%
history = [x for x in y_train]
predictions = list()

# walk-forward validation
for t in range(len(y_test[:253])):
    model = ARIMA(history, order=(2,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = y_test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
# Out:
# predicted=145.813368, expected=143.729996
# predicted=143.720617, expected=145.830002
# predicted=145.928018, expected=143.679993
# predicted=143.617996, expected=144.020004
# predicted=144.087498, expected=143.500000
# predicted=143.500896, expected=144.089996
# predicted=144.125198, expected=142.729996
# predicted=142.714013, expected=144.179993
# predicted=144.243700, expected=145.059998
# predicted=145.056997, expected=145.529999
# predicted=145.533761, expected=145.740005
# predicted=145.748873, expected=147.770004
# predicted=147.810072, expected=149.039993
# predicted=149.032626, expected=149.559998
# predicted=149.557932, expected=150.080002
# predicted=150.093477, expected=151.020004
# predicted=151.040009, expected=150.339996
# predicted=150.327167, expected=150.270004
# predicted=150.299075, expected=152.089996
# predicted=152.134909, expected=152.740005
# predicted=152.728826, expected=153.460007
# predicted=153.474425, expected=150.559998
# predicted=150.518812, expected=149.500000
# predicted=149.560671, expected=148.729996
# predicted=148.755579, expected=150.050003
# predicted=150.102606, expected=157.139999
# predicted=157.254781, expected=155.570007
# predicted=155.402314, expected=156.389999
# predicted=156.451564, expected=158.809998
# predicted=158.845234, expected=160.080002
# predicted=160.064821, expected=161.059998
# predicted=161.066383, expected=155.320007
# predicted=155.231074, expected=157.479996
# predicted=157.649128, expected=159.850006
# predicted=159.841518, expected=161.600006
# predicted=161.582778, expected=160.949997
# predicted=160.915180, expected=157.860001
# predicted=157.851962, expected=157.500000
# predicted=157.593578, expected=157.210007
# predicted=157.232450, expected=159.779999
# predicted=159.840646, expected=159.979996
# predicted=159.932620, expected=159.270004
# predicted=159.272148, expected=159.860001
# predicted=159.904553, expected=161.470001
# predicted=161.494283, expected=162.910004
# predicted=162.905650, expected=163.350006
# predicted=163.335957, expected=164.000000
# predicted=164.015904, expected=164.050003
# predicted=164.051459, expected=162.080002
# predicted=162.067066, expected=161.910004
# predicted=161.977713, expected=161.259995
# predicted=161.272299, expected=158.630005
# predicted=158.623761, expected=161.500000
# predicted=161.626400, expected=160.860001
# predicted=160.794225, expected=159.649994
# predicted=159.668848, expected=158.279999
# predicted=158.311110, expected=159.880005
# predicted=159.955537, expected=158.669998
# predicted=158.629383, expected=158.729996
# predicted=158.780418, expected=156.070007
# predicted=156.052559, expected=153.389999
# predicted=153.437641, expected=151.889999
# predicted=151.950320, expected=150.550003
# predicted=150.581064, expected=153.139999
# predicted=153.228622, expected=154.229996
# predicted=154.198239, expected=153.279999
# predicted=153.253868, expected=154.119995
# predicted=154.173770, expected=153.809998
# predicted=153.800572, expected=154.479996
# predicted=154.514665, expected=153.479996
# predicted=153.464886, expected=155.389999
# predicted=155.459152, expected=155.300003
# predicted=155.267938, expected=155.839996
# predicted=155.866787, expected=155.899994
# predicted=155.904435, expected=156.550003
# predicted=156.574740, expected=156.000000
# predicted=155.993169, expected=156.990005
# predicted=157.034289, expected=159.880005
# predicted=159.915179, expected=160.470001
# predicted=160.424874, expected=159.759995
# predicted=159.751793, expected=155.979996
# predicted=155.955813, expected=156.250000
# predicted=156.368632, expected=156.169998
# predicted=156.178765, expected=157.100006
# predicted=157.133371, expected=156.410004
# predicted=156.392699, expected=157.410004
# predicted=157.459533, expected=163.050003
# predicted=163.134043, expected=166.720001
# predicted=166.672974, expected=169.039993
# predicted=169.031322, expected=166.889999
# predicted=166.803761, expected=168.110001
# predicted=168.204729, expected=172.500000
# predicted=172.588187, expected=174.250000
# predicted=174.201189, expected=174.809998
# predicted=174.799685, expected=176.240005
# predicted=176.281512, expected=175.880005
# predicted=175.855407, expected=174.669998
# predicted=174.666983, expected=173.970001
# predicted=174.000337, expected=171.339996
# predicted=171.306747, expected=169.080002
# predicted=169.097375, expected=171.100006
# predicted=171.226724, expected=170.149994
# predicted=170.095477, expected=169.979996
# predicted=170.016547, expected=173.139999
# predicted=173.243590, expected=174.960007
# predicted=174.949265, expected=174.970001
# predicted=174.943808, expected=174.089996
# predicted=174.084622, expected=173.070007
# predicted=173.082933, expected=169.479996
# predicted=169.422177, expected=171.850006
# predicted=172.019502, expected=171.050003
# predicted=170.990861, expected=169.800003
# predicted=169.805962, expected=169.639999
# predicted=169.684965, expected=169.009995
# predicted=169.015785, expected=169.320007
# predicted=169.361510, expected=169.369995
# predicted=169.381741, expected=172.669998
# predicted=172.771889, expected=171.699997
# predicted=171.614022, expected=172.270004
# predicted=172.325509, expected=172.220001
# predicted=172.223607, expected=173.970001
# predicted=174.032757, expected=176.419998
# predicted=176.460215, expected=174.539993
# predicted=174.452904, expected=174.350006
# predicted=174.409906, expected=175.009995
# predicted=175.049550, expected=175.009995
# predicted=175.012374, expected=170.570007
# predicted=170.479325, expected=170.600006
# predicted=170.731756, expected=171.080002
# predicted=171.109228, expected=169.229996
# predicted=169.190943, expected=172.259995
# predicted=172.394509, expected=172.229996
# predicted=172.170999, expected=173.029999
# predicted=173.067362, expected=175.000000
# predicted=175.044266, expected=174.350006
# predicted=174.304923, expected=174.330002
# predicted=174.364329, expected=174.289993
# predicted=174.308207, expected=175.279999
# predicted=175.322176, expected=177.089996
# predicted=177.126086, expected=176.190002
# predicted=176.143000, expected=179.100006
# predicted=179.204604, expected=179.259995
# predicted=179.213384, expected=178.460007
# predicted=178.457548, expected=177.000000
# predicted=177.005814, expected=177.039993
# predicted=177.095402, expected=174.220001
# predicted=174.174828, expected=171.110001
# predicted=171.118514, expected=171.509995
# predicted=171.611564, expected=167.960007
# predicted=167.885403, expected=166.970001
# predicted=167.038232, expected=167.429993
# predicted=167.480145, expected=167.779999
# predicted=167.796481, expected=160.500000
# predicted=160.335667, expected=156.490005
# predicted=156.549395, expected=163.029999
# predicted=163.343697, expected=159.539993
# predicted=159.295934, expected=155.149994
# predicted=155.195295, expected=156.410004
# predicted=156.616789, expected=162.710007
# predicted=162.817605, expected=164.339996
# predicted=164.127618, expected=167.369995
# predicted=167.404842, expected=172.990005
# predicted=173.066674, expected=172.429993
# predicted=172.224919, expected=171.850006
# predicted=171.872363, expected=171.070007
# predicted=171.087025, expected=172.500000
# predicted=172.589330, expected=175.500000
# predicted=175.554701, expected=178.970001
# predicted=178.990454, expected=178.389999
# predicted=178.260989, expected=178.119995
# predicted=178.152138, expected=175.000000
# predicted=174.928547, expected=176.210007
# predicted=176.382306, expected=176.820007
# predicted=176.812754, expected=176.669998
# predicted=176.661345, expected=175.029999
# predicted=175.002905, expected=176.940002
# predicted=177.079317, expected=179.979996
# predicted=180.022105, expected=181.720001
# predicted=181.680937, expected=179.970001
# predicted=179.864166, expected=178.440002
# predicted=178.478310, expected=178.649994
# predicted=178.737065, expected=178.020004
# predicted=178.009969, expected=175.300003
# predicted=175.253217, expected=175.240005
# predicted=175.364937, expected=171.270004
# predicted=171.158286, expected=168.850006
# predicted=168.930553, expected=164.940002
# predicted=164.893190, expected=172.770004
# predicted=173.176831, expected=168.339996
# predicted=167.997418, expected=166.479996
# predicted=166.613152, expected=167.779999
# predicted=167.897559, expected=166.679993
# predicted=166.624899, expected=168.389999
# predicted=168.486522, expected=171.610001
# predicted=171.641827, expected=172.800003
# predicted=172.730155, expected=168.380005
# predicted=168.247086, expected=170.050003
# predicted=170.277191, expected=173.250000
# predicted=173.272109, expected=172.440002
# predicted=172.305611, expected=174.139999
# predicted=174.229330, expected=174.729996
# predicted=174.692253, expected=175.820007
# predicted=175.839345, expected=178.240005
# predicted=178.270599, expected=177.839996
# predicted=177.752334, expected=172.800003
# predicted=172.719210, expected=165.720001
# predicted=165.734807, expected=165.240005
# predicted=165.539864, expected=162.940002
# predicted=162.903088, expected=163.649994
# predicted=163.777365, expected=164.220001
# predicted=164.228058, expected=162.320007
# predicted=162.256290, expected=165.259995
# predicted=165.438019, expected=169.100006
# predicted=169.124272, expected=176.570007
# predicted=176.735885, expected=176.889999
# predicted=176.657042, expected=183.830002
# predicted=184.106514, expected=185.160004
# predicted=185.063699, expected=186.050003
# predicted=186.074434, expected=187.360001
# predicted=187.411960, expected=190.039993
# predicted=190.140094, expected=188.589996
# predicted=188.491409, expected=188.149994
# predicted=188.184759, expected=186.440002
# predicted=186.400315, expected=188.179993
# predicted=188.306544, expected=186.990005
# predicted=186.924935, expected=186.309998
# predicted=186.328841, expected=187.630005
# predicted=187.716303, expected=187.160004
# predicted=187.131761, expected=188.360001
# predicted=188.436446, expected=188.149994
# predicted=188.135122, expected=188.580002
# predicted=188.620805, expected=187.899994
# predicted=187.883856, expected=187.500000
# predicted=187.518785, expected=186.869995
# predicted=186.873635, expected=190.240005
# predicted=190.402785, expected=191.830002
# predicted=191.837640, expected=193.309998
# predicted=193.355134, expected=193.979996
# predicted=193.995733, expected=193.460007
# predicted=193.445131, expected=191.699997
# predicted=191.660468, expected=191.229996
# predicted=191.268487, expected=192.279999
# predicted=192.352253, expected=190.699997
# predicted=190.634273, expected=190.800003
# predicted=190.857716, expected=188.839996
# predicted=188.779709, expected=188.740005
# predicted=188.796438, expected=185.690002
# predicted=185.590042, expected=186.500000
# predicted=186.610792, expected=185.460007
# predicted=185.423375, expected=184.919998
# predicted=184.937744, expected=182.169998
# predicted=182.090561, expected=184.429993
# predicted=184.586170, expected=184.160004

# %%
fig, ax = plt.subplots(figsize=(15, 6))
plt.plot(np.array(y_test[:253]))
plt.plot(predictions)
ax.set_title('Walk forward validation')
ax.legend(['Expected', 'Predicted'])

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
rmse = sqrt(mean_squared_error(y_test[:253], predictions))
print('RMSE: %.3f' % rmse)
# Out:
# RMSE: 2.247

# %%
model = ARIMA(y_train, order=(2,1,0))
model_fit = model.fit(disp=0)
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
prediction21days = model_fit.predict(start=len(y_train), end=(len(y_train)+253)-1, typ='levels')
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)

# %%
fig, ax = plt.subplots(figsize=(15, 6))
plt.plot(np.array(y_test[:253]))
plt.plot(np.array(prediction21days))
ax.set_title('Prediction 253 days')
ax.legend(['Expected', 'Predicted'])

# %%
rmse = sqrt(mean_squared_error(y_test[:253], prediction21days))
print('RMSE: %.3f' % rmse)
# Out:
# RMSE: 23.564

# %% [markdown]
# ### LSTM Model

# %%
# split a univariate sequence into samples
def split_sequence(sequence, n_steps):
    X, y = list(), list()
    
    for i in range(len(sequence)):
        # find the end of this pattern
        end_ix = i + n_steps
        
        # check if we are beyond the sequence
        if end_ix > len(sequence)-1: break
        
        # gather input and output parts of the pattern
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        
        X.append(seq_x)
        y.append(seq_y)
        
    return np.array(X), np.array(y)

# %%
X, y = split_sequence(y_train, 300)

# %%
X = X.reshape((X.shape[0], X.shape[1], 1))

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout

# %%
model = Sequential()
model.add(LSTM(50, activation='relu', return_sequences=True, input_shape=(300, 1)))
model.add(Dropout(0.2))
model.add(LSTM(50, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
model.fit(X, y, epochs=2)
# Out:
# Epoch 1/2
# 1184/8914 [==>...........................] - ETA: 3:38 - loss: nan
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-564-e28426128484> in <module>
# ----> 1 model.fit(X, y, epochs=2)
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# /anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# /anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Technical Indicators

# %% [markdown]
# I'm gonna make use of this excellent [library](https://technical-analysis-library-in-python.readthedocs.io/en/latest/index.html) for Technical Analysis

# %%
import ta

# %%
def add_technical_indicators(df):
    copy = df.copy()
    
    # Momentum Indicators
    copy['ao'] = ta.momentum.ao(copy['High'], copy['Low'], s=5, len=34, fillna=False)
    copy['mfi_14'] = ta.momentum.money_flow_index(copy['High'], copy['Low'], copy['Close'], copy['Volume'], n=14, fillna=False)
    copy['rsi_14'] = ta.momentum.rsi(copy['Close'], n=14, fillna=False)
    copy['so_14'] = ta.momentum.stoch(copy['High'], copy['Low'], copy['Close'], n=14, fillna=False)
    copy['so_sig_14'] = ta.momentum.stoch_signal(copy['High'], copy['Low'], copy['Close'], n=14, d_n=3, fillna=False)
    copy['tsi'] = ta.momentum.tsi(copy['Close'], r=25, s=13, fillna=False)
    copy['uo'] = ta.momentum.uo(copy['High'], copy['Low'], copy['Close'], s=7, m=14, len=28, ws=4.0, wm=2.0, wl=1.0, fillna=False)
    copy['wr'] = ta.momentum.wr(copy['High'], copy['Low'], copy['Close'], lbp=14, fillna=False)
    
    # Volume Indicators
    copy['adi'] = ta.volume.acc_dist_index(copy['High'], copy['Low'], copy['Close'], copy['Volume'], fillna=False)
    copy['cmf'] = ta.volume.chaikin_money_flow(copy['High'], copy['Low'], copy['Close'], copy['Volume'], n=20, fillna=False)
    copy['eom_20'] = ta.volume.ease_of_movement(copy['High'], copy['Low'], copy['Close'], copy['Volume'], n=20, fillna=False)
    copy['fi2'] = ta.volume.force_index(copy['Close'], copy['Volume'], n=2, fillna=False)
    copy['nvi'] = ta.volume.negative_volume_index(copy['Close'], copy['Volume'], fillna=False)
    copy['obv'] = ta.volume.on_balance_volume(copy['Close'], copy['Volume'], fillna=False)
    copy['vpt'] = ta.volume.volume_price_trend(copy['Close'], copy['Volume'], fillna=False)
    
    # Volatility Indicators
    copy['atr_14'] = ta.volatility.average_true_range(copy['High'], copy['Low'], copy['Close'], n=14, fillna=False)
    copy['b_hband_20'] = ta.volatility.bollinger_hband(copy['Close'], n=20, ndev=2, fillna=False)
    copy['b_hband_ind_20'] = ta.volatility.bollinger_hband_indicator(copy['Close'], n=20, ndev=2, fillna=False)
    copy['b_lband_20'] = ta.volatility.bollinger_lband(copy['Close'], n=20, ndev=2, fillna=False)
    copy['b_lband_ind_20'] = ta.volatility.bollinger_lband_indicator(copy['Close'], n=20, ndev=2, fillna=False)
    copy['mavg_20'] = ta.volatility.bollinger_mavg(copy['Close'], n=20, fillna=False)
    copy['dc_hband_20'] = ta.volatility.donchian_channel_hband(copy['Close'], n=20, fillna=False)
    copy['dc_hband_ind_20'] = ta.volatility.donchian_channel_hband_indicator(copy['Close'], n=20, fillna=False)
    copy['dc_lband_20'] = ta.volatility.donchian_channel_lband(copy['Close'], n=20, fillna=False)
    copy['dc_lband_ind_20'] = ta.volatility.donchian_channel_lband_indicator(copy['Close'], n=20, fillna=False)
    copy['kc10'] = ta.volatility.keltner_channel_central(copy['High'], copy['Low'], copy['Close'], n=10, fillna=False)
    copy['kc_hband_10'] = ta.volatility.keltner_channel_hband(copy['High'], copy['Low'], copy['Close'], n=10, fillna=False)
    copy['kc_hband_ind_10'] = ta.volatility.keltner_channel_hband_indicator(copy['High'], copy['Low'], copy['Close'], n=10, fillna=False)
    copy['kc_lband_10'] = ta.volatility.keltner_channel_lband(copy['High'], copy['Low'], copy['Close'], n=10, fillna=False)
    copy['kc_lband_ind_10'] = ta.volatility.keltner_channel_lband_indicator(copy['High'], copy['Low'], copy['Close'], n=10, fillna=False)

    # Trend Indicators
    copy['adx14'] = ta.trend.adx(copy['High'], copy['Low'], copy['Close'], n=14, fillna=True)
    copy['adx_neg14'] = ta.trend.adx_neg(copy['High'], copy['Low'], copy['Close'], n=14, fillna=True)
    copy['adx_pos14'] = ta.trend.adx_pos(copy['High'], copy['Low'], copy['Close'], n=14, fillna=True)
    copy['ai_down25'] = ta.trend.aroon_down(copy['Close'], n=25, fillna=False)
    copy['ai_up25'] = ta.trend.aroon_up(copy['Close'], n=25, fillna=False)
    copy['cci20'] = ta.trend.cci(copy['High'], copy['Low'], copy['Close'], n=20, c=0.015, fillna=False)
    copy['dpo20'] = ta.trend.dpo(copy['Close'], n=20, fillna=False)
    copy['ema12'] = ta.trend.ema_indicator(copy['Close'], n=12, fillna=False)
    copy['ichimoku_a'] = ta.trend.ichimoku_a(copy['High'], copy['Low'], n1=9, n2=26, visual=False, fillna=False)
    copy['ichimoku_b'] = ta.trend.ichimoku_b(copy['High'], copy['Low'], n2=26, n3=52, visual=False, fillna=False)
    copy['kst'] = ta.trend.kst(copy['Close'], r1=10, r2=15, r3=20, r4=30, n1=10, n2=10, n3=10, n4=15, fillna=False)
    copy['kst_sig'] = ta.trend.kst_sig(copy['Close'], r1=10, r2=15, r3=20, r4=30, n1=10, n2=10, n3=10, n4=15, nsig=9, fillna=False)
    copy['macd'] = ta.trend.macd(copy['Close'], n_fast=12, n_slow=26, fillna=False)
    copy['macd_diff'] = ta.trend.macd_diff(copy['Close'], n_fast=12, n_slow=26, n_sign=9, fillna=False)
    copy['macd_sig'] = ta.trend.macd_signal(copy['Close'], n_fast=12, n_slow=26, n_sign=9, fillna=False)
    copy['mi'] = ta.trend.mass_index(copy['High'], copy['Low'], n=9, n2=25, fillna=False)
    copy['trix_15'] = ta.trend.trix(copy['Close'], n=15, fillna=False)
    copy['vi_neg_14'] = ta.trend.vortex_indicator_neg(copy['High'], copy['Low'], copy['Close'], n=14, fillna=False)
    copy['vi_pos_14'] = ta.trend.vortex_indicator_pos(copy['High'], copy['Low'], copy['Close'], n=14, fillna=False)
    
    # Others Indicators
    copy['cr'] = ta.others.cumulative_return(copy['Close'], fillna=False)
    copy['dlr'] = ta.others.daily_log_return(copy['Close'], fillna=False)
    copy['dr'] = ta.others.daily_return(copy['Close'], fillna=False)
    
    return copy.dropna() # we drop all the rows that contain at least one NaN

# %%
apple_stock_TA = add_technical_indicators(apple_stock)

# %%
apple_stock_TA.head()
# Out:
#                 Open      High       Low     Close     Volume        ao  \
# Date
# 1981-02-13  0.459821  0.459821  0.455357  0.455357  2788800.0 -0.074363
# 1981-02-17  0.466518  0.468750  0.466518  0.466518  3068800.0 -0.073418
# 1981-02-18  0.486607  0.491071  0.486607  0.486607  4810400.0 -0.069092
# 1981-02-19  0.459821  0.459821  0.457589  0.457589  5577600.0 -0.067306
# 1981-02-20  0.435268  0.435268  0.433036  0.433036  6092800.0 -0.068586
#
#                mfi_14     rsi_14      so_14     so_sig_14  ...      macd  \
# Date                                                       ...
# 1981-02-13  21.310431  21.924184   0.000000  1.421085e-14  ... -0.023583
# 1981-02-17  26.718969  31.624112  11.111332  3.703777e+00  ... -0.023955
# 1981-02-18  35.173352  45.648056  38.888958  1.666676e+01  ... -0.022412
# 1981-02-19  39.133343  34.018973   3.703458  1.790125e+01  ... -0.023205
# 1981-02-20  43.916408  27.243107   0.000000  1.419747e+01  ... -0.025474
#
#             macd_diff  macd_sig         mi   trix_15  vi_neg_14  vi_pos_14  \
# Date
# 1981-02-13  -0.006325 -0.017259  25.798652 -0.513847   1.063830   0.861697
# 1981-02-17  -0.005341 -0.018614  25.660389 -0.549274   1.020411   0.887749
# 1981-02-18  -0.003032 -0.019380  25.669583 -0.570668   0.970303   0.900987
# 1981-02-19  -0.003054 -0.020151  25.653314 -0.592602   0.980954   0.904759
# 1981-02-20  -0.004252 -0.021222  25.485432 -0.622534   0.980584   0.912622
#
#                    cr       dlr        dr
# Date
# 1981-02-13 -11.304400 -2.421488 -2.392405
# 1981-02-17  -9.130432  2.421488  2.451044
# 1981-02-18  -5.217446  4.216021  4.306158
# 1981-02-19 -10.869646 -6.148541 -5.963334
# 1981-02-20 -15.652142 -5.515054 -5.365732
#
# [5 rows x 57 columns]

# %%
apple_stock_TA.describe()

# %% [markdown]
# Let's plot all this indicators:

# %%
def plot_columns(columns, df, fromTo=None):
    fig, ax = plt.subplots(figsize=(15, 6))
    
    if fromTo is not None:
        df = get_range(fromTo[0], fromTo[1], df)
        
    for column in columns:
        df.reset_index().plot(ax=ax, x='Date', y=column)

# %%
plot_columns(['Close', 'MA10', 'MA20', 'MA50', 'BBU', 'BBL'], apple_stock_TA, fromTo=('2018-1-1', '2018-12-31'))

# %%
plot_columns(['Close', 'AO', 'ADX', 'MACD'], apple_stock_TA, fromTo=('2017-1-1', '2018-12-31'))

# %% [markdown]
# ### Other features and assets

# %% [markdown]
# Let's add more features. How about adding the CPI?. We need to first add all the missing days in cpi since the frequency of this index is monthly:

# %%
idx_date = pd.date_range(cpi.index[0], cpi.index[-1])
cpi_full = cpi.reindex(idx_date)
cpi_full.fillna(method='ffill', inplace=True)

# %%
cpi_full.head(n=35)

# %%
apple_stock_TA_plus = pd.merge(apple_stock_TA, cpi_full, left_index=True, right_index=True)

# %%
apple_stock_TA_plus.head()

# %%
# https://en.wikipedia.org/wiki/VIX
vix = load_csv_with_dates('datasets/VIX_yahoo-finance_19900102-20190531.csv')

# %%
plot_field_over_time(vix, title='VIX', ylabel='Volatility')

# %%
# https://en.wikipedia.org/wiki/NASDAQ-100
ndx = load_csv_with_dates('datasets/NDX_yahoo-finance_19851001-20190531.csv')

# %%
plot_field_over_time(ndx, title='NASDAQ-100', ylabel='Price', ylegend='Close Price')

# %%
apple_stock_TA_plus2 = pd.merge(apple_stock_TA_plus, 
                                vix['Close'], 
                                left_index=True, 
                                right_index=True, suffixes=('', '_VIX'))

# %%
apple_stock_TA_plus2 = pd.merge(apple_stock_TA_plus2, 
                                ndx['Close'], 
                                left_index=True, 
                                right_index=True, suffixes=('', '_NDX'))

# %%
apple_stock_TA_plus2.head()

# %% [markdown]
# ### Feature Importance

# %%
from xgboost import XGBRegressor, plot_importance
from sklearn.model_selection import train_test_split

# %%
apple_stock2 = apple_stock_TA_plus2.drop(columns='Adj Close') # We don't need this column

X = apple_stock2.drop(columns='Close')
y = apple_stock2['Close']

X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=0.30, random_state=42, shuffle=False)

# %%
regressor = XGBRegressor()

# %%
regressor.fit(X_train, y_train, eval_set=[(X_test, y_test)], verbose=False)

# %%
fig, ax = plt.subplots(figsize=(20, 0))
plot_importance(regressor, ax=ax)

# %% [markdown]
# How about calculating the importance of the features to predict next day price?

# %%
X_train_1 = X_train[:-1]
y_train_1 = y_train[1:]
X_test_1 = X_test[:-1]
y_test_1 = y_test[1:]

# %%
regressor_1 = XGBRegressor()
regressor_1.fit(X_train_1, y_train_1, eval_set=[(X_test_1, y_test_1)], verbose=False)

# %%
fig, ax = plt.subplots(figsize=(20, 20))
plot_importance(regressor_1, ax=ax)

# %% [markdown]
# next few weeks?

# %%
X_train_15 = X_train[:-15]
y_train_15 = y_train[15:]
X_test_15 = X_test[:-15]
y_test_15 = y_test[15:]

# %%
regressor_15 = XGBRegressor()
regressor_15.fit(X_train_15, y_train_15, eval_set=[(X_test_15, y_test_15)], verbose=False)

# %%
fig, ax = plt.subplots(figsize=(20, 20))
plot_importance(regressor_15, ax=ax)

# %% [markdown]
# next month?

# %%
X_train_21 = X_train[:-21]
y_train_21 = y_train[21:]
X_test_21 = X_test[:-21]
y_test_21 = y_test[21:]

# %%
regressor_21 = XGBRegressor()
regressor_21.fit(X_train_21, y_train_21, eval_set=[(X_test_21, y_test_21)], verbose=False)

# %%
fig, ax = plt.subplots(figsize=(20, 20))
plot_importance(regressor_21, ax=ax)

# %% [markdown]
# next year?

# %%
X_train_252 = X_train[:-252]
y_train_252 = y_train[252:]
X_test_252 = X_test[:-252]
y_test_252 = y_test[252:]

# %%
regressor_252 = XGBRegressor()
regressor_252.fit(X_train_252, y_train_252, eval_set=[(X_test_252, y_test_252)], verbose=False)

# %%
fig, ax = plt.subplots(figsize=(20, 30))
plot_importance(regressor_252, ax=ax)

# %% [markdown]
# Interesting to see how this chart confirms the use of these features to predict future price movements

# %% [markdown]
# ### Feature Distributions

# %%
import seaborn as sns

features_raw = apple_stock2.drop(columns='Close')

features_raw_corr = features_raw.corr()

fig, ax = plt.subplots(figsize=(15, 10))
sns.heatmap(features_raw_corr, cmap='magma', ax=ax)

# %% [markdown]
# As we can see, many features are highly correlated. Let's have a look at the distribution:

# %%
ncols=2
nrows=10
column_names = features_raw.columns.values

fig, axs = plt.subplots(nrows=nrows, ncols=ncols, figsize=(12, 12))
fig.tight_layout()

c = 0
r = 0

for name in column_names:
    sns.distplot(apple_stock2[name], hist=False, ax=axs[r, c])
    
    axs[r, c].get_yaxis().set_ticklabels([])
    
    if (c < ncols - 1):
        c = c + 1
    else:
        c = 0
        r = r + 1

# %% [markdown]
# ### Feature Normalization

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# # Initialize a scaler, then apply it to the features
# scaler = MinMaxScaler() # default=(0, 1)

# features_log_minmax_transform = pd.DataFrame(data=features_log_transformed)
# features_log_minmax_transform = scaler.fit_transform(features_log_transformed)

# # Show an example of a record with scaling applied
# features_log_minmax_transform[:5]

# %%
# features_log_minmax_transform_df = pd.DataFrame(features_log_minmax_transform, 
#                                   index=features_log_transformed.index, 
#                                   columns=features_log_transformed.columns)

# %%
# features_log_minmax_transform_df.head()
