# %% [markdown]
# ### Data Exploration & Visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Loading Apple Inc. stock prices that can be easily downloaded for free from [Yahoo! Finance](https://finance.yahoo.com/quote/AAPL/history?p=AAPL)

# %%
apple_stock = pd.read_csv('datasets/AAPL_yahoo-finance_19801212-20190531.csv', 
                          index_col=0, 
                          parse_dates=True, 
                          infer_datetime_format=True)

# %%
apple_stock.head()
# Out:
#                 Open      High       Low     Close  Adj Close       Volume
# Date
# 1980-12-12  0.513393  0.515625  0.513393  0.513393   0.022919  117258400.0
# 1980-12-15  0.488839  0.488839  0.486607  0.486607   0.021723   43971200.0
# 1980-12-16  0.453125  0.453125  0.450893  0.450893   0.020129   26432000.0
# 1980-12-17  0.462054  0.464286  0.462054  0.462054   0.020627   21610400.0
# 1980-12-18  0.475446  0.477679  0.475446  0.475446   0.021225   18362400.0

# %%
print('Total data points: {}'.format(len(apple_stock)))
print('From {} to {}'.format(apple_stock.index[0], apple_stock.index[-1]))
# Out:
# Total data points: 9699
# From 1980-12-12 00:00:00 to 2019-05-31 00:00:00

# %% [markdown]
# Let's plot the closing prices over time

# %%
ax = apple_stock.reset_index().plot(x='Date', 
                                    y='Close', 
                                    figsize=(12, 4), 
                                    title='Apple Inc. (AAPL)')
ax.set_xlabel('Year')
ax.set_ylabel('Price')
ax.legend(['Close Price'])

# %% [markdown]
# How about the volumen?

# %%
ax = apple_stock.reset_index().plot(x='Date', 
                                    y='Volume', 
                                    figsize=(12, 4), 
                                    title='Apple Inc. (AAPL)')
ax.set_xlabel('Year')
ax.set_ylabel('Trading Volume')
# Out:
# Text(0, 0.5, 'Trading Volume')

# %% [markdown]
# Let's zoom in and plot 2018 prices:

# %%
def get_range(start, end, df):
    return df[(df.index >= start) & (df.index <= end)]

# %%
apple_stock_2018 = get_range('2018-01-01', '2018-12-31', apple_stock)

# %%
ax = apple_stock_2018.reset_index().plot(x='Date', 
                                         y='Close', 
                                         figsize=(12, 4), 
                                         title='Apple Inc. in 2018')
ax.set_xlabel('Year 2018')
ax.set_ylabel('Price')
ax.legend(['Close Price'])

# %% [markdown]
# A nice visualization would be using candlesticks. We need to import the necessary libs

# %%
import matplotlib.dates as mdates
from mpl_finance import candlestick_ohlc

# %%
def plot_candlestick(title, xlabel, ylabel, df):
    fig, ax = plt.subplots(figsize=(12, 4))
    candlestick_ohlc(ax, 
                     zip(mdates.date2num(df.index.to_pydatetime()), 
                         df['Open'], 
                         df['High'], 
                         df['Low'], 
                         df['Close']), 
                     width=0.6, 
                     colorup='g')
    ax.xaxis_date()
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    plt.show()

# %%
plot_candlestick('Apple Inc. in 2018', 'Year 2018', 'Price', apple_stock_2018)

# %% [markdown]
# Let's zoom in a bit more. Dec 2018:

# %%
apple_stock_201812 = get_range('2018-12-01', '2018-12-31', apple_stock)

# %%
plot_candlestick('Apple Inc. in 2018-12', 'Dec 2018', 'Price', apple_stock_201812)

# %% [markdown]
# I'd be curious to know what the time series look like after adjusting inflation. We need to first load the [Consumer Price Index for All Urban Consumers: All Items](https://fred.stlouisfed.org/series/CPIAUCSL)

# %%
cpi = pd.read_csv('datasets/CPIAUCSL_FRED_19470101-20190401.csv', 
                  index_col=0,
                  parse_dates=True, 
                  infer_datetime_format=True)

# We need to rename the index to be able to merge later on
cpi.rename_axis('Date', inplace=True)

# %%
cpi.head()
# Out:
#             CPIAUCSL
# Date
# 1947-01-01     21.48
# 1947-02-01     21.62
# 1947-03-01     22.00
# 1947-04-01     22.00
# 1947-05-01     21.95

# %%
print('Consumer Price Index from {} to {}'.format(cpi.index[0], cpi.index[-1]))
# Out:
# Consumer Price Index from 1947-01-01 00:00:00 to 2019-04-01 00:00:00

# %% [markdown]
# Let's visualize the inflation:

# %%
ax = cpi.reset_index().plot(x='Date', 
                            y='CPIAUCSL', 
                            figsize=(12, 4), 
                            title='Consumer Price Index')

# %% [markdown]
# We're gonna add a new column, CPI_multiplier ([reference](https://towardsdatascience.com/adjusting-prices-for-inflation-in-pandas-daaaa782cd89))

# %%
cpi['CPI_Multiplier'] = cpi['CPIAUCSL'].iloc[-1] / cpi['CPIAUCSL']

# %%
cpi.tail()
# Out:
#             CPIAUCSL  CPI_Multiplier
# Date
# 2018-12-01   252.723        1.008844
# 2019-01-01   252.673        1.009043
# 2019-02-01   253.113        1.007289
# 2019-03-01   254.148        1.003187
# 2019-04-01   254.958        1.000000

# %%
apple_stock_with_cpi = pd.merge(apple_stock, cpi, left_index=True, right_index=True)

# %%
apple_stock_with_cpi['CPIAdjustedPrice'] = \
    apple_stock_with_cpi['Close'] * apple_stock_with_cpi['CPI_Multiplier']

# %%
ax = apple_stock_with_cpi.reset_index().plot(x='Date', 
                                             y='CPIAdjustedPrice', 
                                             figsize=(12, 4), 
                                             title='Apple Inc. with adjusted inflation')
ax.set_xlabel('Year')
ax.set_ylabel('Price')
ax.legend(['Close Price'])
